# %%
#所有代码
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

y1 = pd.read_excel(r'D:\#条形码系统\盘点\库存对照\《资材》材料在库数据_2001081346.xlsx',usecols=[1,4,5,6,31])
y2 = pd.read_excel(r'D:\#条形码系统\盘点\库存对照\《资材》材料在库数据_2001081346.xlsx',usecols=[1,4,5,6,31])
y2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

y1 = pd.read_excel(r'D:\#条形码系统\盘点\库存对照\《资材》材料在库数据_2001081346.xlsx',usecols=[1,4,5,6,31])
y2 = pd.read_excel(r'D:\#条形码系统\盘点\库存对照\《资材》材料在库数据_2001081346.xlsx',usecols=[1,4,5,6,31])
y2
# Out:
#             资材编号           品名                  规格   单位    现库存数量
# 0     BF00C50001        铁氧体磁芯           W-W02228A  PCS     40.0
# 1     BF26M00050        底漆稀释剂                  HK  PCS      0.0
# 2     BF26M00051         米黄面漆              PC2000  PCS      0.0
# 3     BF26M00052         灰色底漆        UNIGROUND930  PCS      0.0
# 4     BF26M00053          固化剂              PC2000  PCS      0.0
# ...          ...          ...                 ...  ...      ...
# 7855  TT79A21451  绝缘管79A21451           φ11.7X137  PCS      0.0
# 7856  TT79A5T006         橡胶衬套            U5972G01  PCS    100.0
# 7857  TT79B31017      电缆夹(TY)  U5035K02(U4167F02)  PCS      0.0
# 7858  TT79B31028       螺母(TY)            U4167F03  PCS     10.0
# 7859  TT79E00805          开关盖            U2853C05  PCS  11310.0
#
# [7860 rows x 5 columns]

# %%
y2 = pd.read_excel(r'D:\#条形码系统\盘点\库存对照\《资材》材料在库数据_2001091241.xlsx',usecols=[1,4,5,6,31])
y2
# Out:
#             资材编号           品名                  规格   单位    现库存数量
# 0     BF00C50001        铁氧体磁芯           W-W02228A  PCS     40.0
# 1     BF26M00050        底漆稀释剂                  HK  PCS      0.0
# 2     BF26M00051         米黄面漆              PC2000  PCS      0.0
# 3     BF26M00052         灰色底漆        UNIGROUND930  PCS      0.0
# 4     BF26M00053          固化剂              PC2000  PCS      0.0
# ...          ...          ...                 ...  ...      ...
# 7855  TT79A21451  绝缘管79A21451           φ11.7X137  PCS      0.0
# 7856  TT79A5T006         橡胶衬套            U5972G01  PCS    100.0
# 7857  TT79B31017      电缆夹(TY)  U5035K02(U4167F02)  PCS      0.0
# 7858  TT79B31028       螺母(TY)            U4167F03  PCS     10.0
# 7859  TT79E00805          开关盖            U2853C05  PCS  11310.0
#
# [7860 rows x 5 columns]

# %%
y = pd.merge(y1,y2,on='资材编号')
# Out:
#             资材编号         品名_x                规格_x 单位_x  现库存数量_x         品名_y  \
# 0     BF00C50001        铁氧体磁芯           W-W02228A  PCS     40.0        铁氧体磁芯
# 1     BF26M00050        底漆稀释剂                  HK  PCS      0.0        底漆稀释剂
# 2     BF26M00051         米黄面漆              PC2000  PCS      0.0         米黄面漆
# 3     BF26M00052         灰色底漆        UNIGROUND930  PCS      0.0         灰色底漆
# 4     BF26M00053          固化剂              PC2000  PCS      0.0          固化剂
# ...          ...          ...                 ...  ...      ...          ...
# 7855  TT79A21451  绝缘管79A21451           φ11.7X137  PCS      0.0  绝缘管79A21451
# 7856  TT79A5T006         橡胶衬套            U5972G01  PCS    100.0         橡胶衬套
# 7857  TT79B31017      电缆夹(TY)  U5035K02(U4167F02)  PCS      0.0      电缆夹(TY)
# 7858  TT79B31028       螺母(TY)            U4167F03  PCS     10.0       螺母(TY)
# 7859  TT79E00805          开关盖            U2853C05  PCS  11310.0          开关盖
#
#                     规格_y 单位_y  现库存数量_y
# ...

# %%
y.to_excel(excel_writer=r'D:\#条形码系统\盘点\库存对照\temp01.xlsx')
