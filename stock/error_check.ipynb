# %% [markdown]
# ## 系统回写错误分析

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#设置pandas
pd.set_option('max_columns', 20)
pd.set_option('max_rows', 20)
pd.set_option('display.float_format', lambda x: '%.2f' % x) # 禁用科学计数法
#pd.set_option('display.max_rows',None)

#打开文件
fpath = r'D:/#条形码系统/盘点/库存对照/err/'
xlout = pd.read_excel(fpath+'领料出库单列表_指示编号取消.xlsx',usecols=[0,1,3,6,7,8,9,10,16])
xlout['单据编号'] = xlout.apply(lambda x:str(x.单据编号[:6]),axis=1)
xlerr = pd.read_excel(fpath+'出库数据同步失败.xlsx',usecols=[2,3,4,5])
xlerr['单据编号'] = xlerr.apply(lambda x:str(x.单据编号),axis=1)
df = pd.merge(xlerr,xlout,on='单据编号',how='left').fillna(0)
df[df['资材编号']!=0]
# Out:
#        单据编号  出库批次     数量       出库时间   指示编号      安排出库日期        资材编号      品名  \
# 229  755278     0  -0.24 2019-06-03  P7562           0  MD22D20024     绝缘管
# 230  755279     0 -17.22 2019-06-03  P7562           0  MC00A80393      铁芯
# 231  755280     0  -2.50 2019-06-03  P7562           0  MC00A80393      铁芯
# 232  755281     0  -2.00 2019-06-03  P7562           0  JJ22A20003    绝缘胶带
# 233  755282     0  -1.05 2019-06-03  P7562           0  MB01M00006     冷轧板
# ..      ...   ...    ...        ...    ...         ...         ...     ...
# 796  540035     1  12.00 2019-12-26  Y0282  2018/08/28  TT32E01841  弹垫(TY)
# 797  540043     1  12.00 2019-12-26  Y0282  2018/08/28  TT32E01841  弹垫(TY)
# 798  540067     1  48.00 2019-12-26  Y0282  2018/08/28  TT32E01841  弹垫(TY)
# 799  540092     1   6.00 2019-12-26  Y0282  2018/08/28  JC31B54833    六角螺栓
# 801  540059     1  24.00 2019-12-26  Y0282  2018/08/28  JJ31B50913  六角十字螺栓
#
#                          规格 计量单位  计划数量            仓库完成日期
# ...

# %%
xlerr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 4 columns):
# 单据编号    804 non-null object
# 出库批次    804 non-null int64
# 数量      804 non-null float64
# 出库时间    804 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 25.2+ KB
